# %% [markdown]
# # Capstone Project  -  The Battle of Neighborhood

# %% [markdown]
# # Business problem

# %% [markdown]
# **Background:**
#
#   As the COVID-19 situation came for the first half year of 2020, the house price in the United States falls sharply for the decrease of demand. The low price might attract investors around the world who consider the current house price is undervalued.

# %% [markdown]
# **Business Problem:**
#  In this senerio, the ABC real estate company realized that there might be some investors who are not familiar with the real estate market in Manhattan. They are considering about what they can do to help those investors to gather more information?
#  In order to solve this problem and generate joint profit for both parties, the ABC real estate plan to cluster Manhattan's neighborhoods for recommending suitable price and venues to their investors

# %% [markdown]
# **Data Selection:**
# The data of real estate price comes from the link (https://www1.nyc.gov/site/finance/taxes/property-rolling-sales-data.page) which is a open source from nyc government
# To explore and target recommended locations across different venues according to the presence of amenities and essential facilities, we will access data through FourSquare API interface and arrange them as a dataframe for visualization.The venue data from foursquare including：Neighborhood's (Name,Latitude,Longtitude,venue,name,latitude,longtitude of venues)

# %% [markdown]
# **Methodology:**
# In this case, I'll use data cleaning methods from IBM data science class and Kmeans and clustering for modeling.
# The specific process is showned below

# %% [markdown]
# **Result and Discussion:**
# ![gg1.PNG](attachment:gg1.PNG)
# Here is the graph showing the result of clustering in Manhattan which suggest there are variety of features for different kind of investors.
#
# ![gg2.PNG](attachment:gg2.PNG)
# This is the graph shows the average price of each neighborhoods in Manhattan which suggest there is variety of price from $200 per/SQFT to $1600 per/SQFT for investor which fit most investors around the world

# %% [markdown]
# **Discusstion Section:**
# The major business problem in this project is to process and visulize data in order to help the investors to make their investment decision on real estate market. To achieve this goal, we successfully process the real estate price and calculate their average price of each neiborhood and sort it ascendingly. The result of housing price is shown above that is efficient for investors to make their decision.
# Venue is another aspect that considered by house buyer. Our project sucessfully seperate the neighborhoods based on their venues to 5 patterns and I believe it will help home buyers for their decision making. For instance, people who consider the apartment near park is more profitable would choose the apartment in cluster 4 which has park as its most common venue.

# %% [markdown]
# **Conclusion:**
#   To make conclusion for this project,we find that there is a drop on the price of real estate market in the United States due to the COVID-19 situation which decrease customers' purchasing power. Therefore, we consider that at the same time there would be investors who holds differnet opinion that they think right now is a great timing for making investorment. So that our ABC company decides to analyze and visulize real estate data in Manhattan to assist investors to make their decision.
#   In the first place, we gathered data on Manhattan real estates' price on 2019 which is the most recent price data from ((https://www1.nyc.gov/site/finance/taxes/property-rolling-sales-data.page)  Moreover, to explore and target recommended locations across different venues according to the presence of amenities and essential facilities, we accessed data through FourSquare API interface and arranged them as a data frame for visualization. By merging data on Manhattan's average price of each neighborhood and essential facilities surrounding such neighborhoods from FourSquare API interface, we were able to recommend profitable real estate investments.
#   The project follows the workflow as "Collecting data - understanding data - processing data - data modeling - Visualize data". in the modeling section, we used the k-means clustering technique as it is fast and efficient in terms of computational cost.
#   Finally, we grab the result that generated by k-mean clustering as the graph shows below which contains 5 different clusters with differnt feature and range in differnet price although there is N/A on some price value which is caused by missing data from data source. I believe the current real estate market in Manhattan is highly diverse and it fits investors with differnet appitates.
#   ![gg3.PNG](attachment:gg3.PNG)
#   ![gg4.PNG](attachment:gg4.PNG)
